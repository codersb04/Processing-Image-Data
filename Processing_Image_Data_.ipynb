# %%
# Getting the image through a link using web get command
# !wget 'https://media-cldnry.s-nbcnews.com/image/upload/rockcms/2023-03/puppy-dog-mc-230321-03-b700d4.jpg'
# Out:
# --2023-10-05 08:38:31--  https://media-cldnry.s-nbcnews.com/image/upload/rockcms/2023-03/puppy-dog-mc-230321-03-b700d4.jpg
# Resolving media-cldnry.s-nbcnews.com (media-cldnry.s-nbcnews.com)... 23.209.49.108, 2600:1408:5400:4a0::a1d, 2600:1408:5400:48f::a1d
# Connecting to media-cldnry.s-nbcnews.com (media-cldnry.s-nbcnews.com)|23.209.49.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1132388 (1.1M) [image/jpeg]
# Saving to: ‘puppy-dog-mc-230321-03-b700d4.jpg’
#
# puppy-dog-mc-230321 100%[===================>]   1.08M  --.-KB/s    in 0.05s
#
# 2023-10-05 08:38:31 (23.5 MB/s) - ‘puppy-dog-mc-230321-03-b700d4.jpg’ saved [1132388/1132388]

# %% [markdown]
# Libraries for Image processing are:
# 1. matplotlib.image
# 2. Pillow
# 3. OpenCV(cv2)

# %%
# Importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# Raname the Image file to dog.jpg

# %%
# Loading the image through matplotlib.image module

img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1667, 2500, 3)

# %% [markdown]
# 1st and 2nd values refer to the dimension and last value depicts the Colour Channels

# %%
img
# Out:
# array([[[ 70,  45,  15],
#         [ 72,  47,  17],
#         [ 70,  45,  15],
#         ...,
#         [ 24,  24,  22],
#         [ 25,  25,  23],
#         [ 26,  26,  24]],
#
#        [[ 72,  47,  17],
#         [ 72,  47,  17],
#         [ 71,  46,  16],
#         ...,
#         [ 27,  27,  25],
#         [ 29,  29,  27],
#         [ 26,  26,  24]],
#
#        [[ 69,  44,  13],
#         [ 72,  47,  16],
#         [ 74,  49,  18],
#         ...,
#         [ 31,  31,  29],
#         [ 26,  26,  24],
#         [ 28,  28,  26]],
#
#        ...,
#
#        [[214, 205, 232],
#         [214, 205, 232],
#         [211, 202, 229],
#         ...,
#         [ 98,  80, 122],
#         [104,  86, 126],
#         [118,  95, 137]],
#
#        [[210, 201, 228],
#         [211, 202, 229],
#         [210, 201, 228],
#         ...,
#         [ 95,  80, 121],
#         [ 92,  77, 116],
#         [ 97,  79, 119]],
#
#        [[210, 201, 228],
#         [211, 202, 229],
#         [210, 201, 228],
#         ...,
#         [ 99,  84, 125],
#         [ 96,  81, 120],
#         [ 95,  77, 117]]], dtype=uint8)

# %%
# display the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# **Resizing the image using Pillow Library**

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')

# %%
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# Loading the image through matplotlib.image module

img_reshapped = mpimg.imread('/content/dog_image_resized.jpg')

# %%
img_reshapped.shape
# Out:
# (200, 200, 3)

# %%
img_plot = plt.imshow(img_reshapped)
plt.show()

# %% [markdown]
# **Converting the RGB image to Gray Scale images using OpenCV**

# %%
# importing openCV library
import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1667, 2500, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1667, 2500)

# %% [markdown]
# cv2.imshow() will display the image but this will not be allowed in google colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
# display the image from numpy array un=sing matplotlib

img_plot = plt.imshow(grayscale_image)
plt.show()

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the grayscale image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=2500x1667>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg',grayscale_image)
# Out:
# True
